# %% [markdown]
# # Chronos model

# %%
from chronos_model import ChronosModel

# %%
chronos_univ = ChronosModel()
chronos_univ.forecast()
chronos_univ.plot_predictions(4,'national')
chronos_univ.save_predictions()
# Out:
# ...
# states for dataset 4: 100%|████████████████████████████████████████████████████████████████████████████| 27/27 [00:21<00:00,  1.25it/s]
